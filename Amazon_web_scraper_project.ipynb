# %%
# import libraries

from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
# Connect to Website and pull in data

URL = 'https://www.amazon.com/Data-Analyst-Definition-Scientist-Expert/dp/B0CVTSG4BB/ref=sr_1_12?crid=27EFCSQM63XMR&dib=eyJ2IjoiMSJ9.TuY8uz5Xjkurb0g262hcHAQ5gzH0mr0TxOE3J05n1-y8w6b4jO4ebirco2AIvKTBtWCKgveQxLrETbMlrg0fHoyDkbUIquXtdJ3g0D_TiR_QoDX0IWlDkREiKBfDNIJP0-pwaIvDdYFRxnTyi5bDfsBbmR6vOTXdqIenCJFBaGTLeB5Id9ueFeR2Ntv-fPloVOi6a4Knb58nOsRB2g_Bo_2fADMgqufSBY1caVNSEClgmv2lq0ir4fmxL1-zvlM7thyLJn6hvzAdnUq6c_3xtYXNeISOjmNVmM01f6esqxw.Cz7E21zgWTuRsMSjOXTa6x3ZrMJ6PrZyG1CNUUof7Po&dib_tag=se&keywords=data%2Banalyst%2Btshirt&qid=1764148117&sprefix=data%2Banalyst%2Btshir%2Caps%2C310&sr=8-12&customId=B0752XJYNL&customizationToken=MC_Assembly_1%23B0752XJYNL&th=1&psc=1'




headers = { "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36" ,   "Accept-Language": "en-GB,en;q=0.9",  "Accept-Encoding": "gzip, deflate, br, zstd"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, 'html.parser')

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

title = soup2.find(id='productTitle').get_text()

rating = soup2.find('span' , {'class': 'a-size-base'}).get_text()




print(title)
print(rating)
# Out:
#                  Data Analyst Definition Data Scientist Data Science Expert T-Shirt
#
#
#                     5.0

# %%
# Clean up the data a little bit

rating = rating.strip()[:1]
title = title.strip()

print(title)
print(rating)
# Out:
# Data Analyst Definition Data Scientist Data Science Expert T-Shirt
# 5

# %%
# Create a Timestamp for your output to track when data was collected
today = datetime.date.today()
print(today)
# Out:
# 2025-12-01

# %%
# Create CSV and write headers and data into the file

import csv

headers = ['Title' , 'Rating' , 'Date']

data = [title , rating , today]

# with open('AmazonWebScraperDataset.csv' , 'w' , newline='', encoding='UTF8') as f:
#     writer = csv.writer(f)
#     writer.writerow(headers)
#     writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv('AmazonWebScraperDataset.csv')

df
# Out:
#                                                Title  Rating        Date
# 0  Data Analyst Definition Data Scientist Data Sc...       5  2025-12-01
# 1  Data Analyst Definition Data Scientist Data Sc...       5  2025-12-01
# 2  Data Analyst Definition Data Scientist Data Sc...       5  2025-12-01

# %%
#Now we are appending data to the csv
with open('AmazonWebScraperDataset.csv' , 'a+' , newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
#Combine all of the above code into one function
def check_rating():

  URL = 'https://www.amazon.com/Data-Analyst-Definition-Scientist-Expert/dp/B0CVTSG4BB/ref=sr_1_12?crid=27EFCSQM63XMR&dib=eyJ2IjoiMSJ9.TuY8uz5Xjkurb0g262hcHAQ5gzH0mr0TxOE3J05n1-y8w6b4jO4ebirco2AIvKTBtWCKgveQxLrETbMlrg0fHoyDkbUIquXtdJ3g0D_TiR_QoDX0IWlDkREiKBfDNIJP0-pwaIvDdYFRxnTyi5bDfsBbmR6vOTXdqIenCJFBaGTLeB5Id9ueFeR2Ntv-fPloVOi6a4Knb58nOsRB2g_Bo_2fADMgqufSBY1caVNSEClgmv2lq0ir4fmxL1-zvlM7thyLJn6hvzAdnUq6c_3xtYXNeISOjmNVmM01f6esqxw.Cz7E21zgWTuRsMSjOXTa6x3ZrMJ6PrZyG1CNUUof7Po&dib_tag=se&keywords=data%2Banalyst%2Btshirt&qid=1764148117&sprefix=data%2Banalyst%2Btshir%2Caps%2C310&sr=8-12&customId=B0752XJYNL&customizationToken=MC_Assembly_1%23B0752XJYNL&th=1&psc=1'




  headers = { "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36" ,   "Accept-Language": "en-GB,en;q=0.9",  "Accept-Encoding": "gzip, deflate, br, zstd"}

  page = requests.get(URL, headers=headers)

  soup1 = BeautifulSoup(page.content, 'html.parser')

  soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

  title = soup2.find(id='productTitle').get_text()

  rating = soup2.find('span' , {'class': 'a-size-base'}).get_text()

  rating = rating.strip()[:1]
  title = title.strip()

  today = datetime.date.today()

  import csv

  headers = ['Title' , 'Rating' , 'Date']

  data = [title , rating , today]

  with open('AmazonWebScraperDataset.csv' , 'a+' , newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
# Runs check_rating after a set time and inputs data into your CSV

while(True):
  check_rating()
  time.sleep(86400)

# %%
import pandas as pd

df = pd.read_csv('AmazonWebScraperDataset.csv')

df
# Out:
#                                                Title  Rating        Date
# 0  Data Analyst Definition Data Scientist Data Sc...       5  2025-12-01
# 1  Data Analyst Definition Data Scientist Data Sc...       5  2025-12-01
# 2  Data Analyst Definition Data Scientist Data Sc...       5  2025-12-01
# 3  Data Analyst Definition Data Scientist Data Sc...       5  2025-12-01
# 4  Data Analyst Definition Data Scientist Data Sc...       5  2025-12-01
# 5  Data Analyst Definition Data Scientist Data Sc...       5  2025-12-01
# 6  Data Analyst Definition Data Scientist Data Sc...       5  2025-12-01
# 7  Data Analyst Definition Data Scientist Data Sc...       5  2025-12-01

# %%
# if the rating is higher  a certain level, send an email alert


def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('jayandrahamal203@gmail.com','xxxxxxxxxxxxxx')
    
    subject = "The Shirt you want has high rating! Now is your chance to buy!"
    body = "jayandra, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here: https://www.amazon.com/Data-Analyst-Definition-Scientist-Expert/dp/B0CVTSG4BB/ref=sr_1_12?crid=27EFCSQM63XMR&dib=eyJ2IjoiMSJ9.TuY8uz5Xjkurb0g262hcHAQ5gzH0mr0TxOE3J05n1-y8w6b4jO4ebirco2AIvKTBtWCKgveQxLrETbMlrg0fHoyDkbUIquXtdJ3g0D_TiR_QoDX0IWlDkREiKBfDNIJP0-pwaIvDdYFRxnTyi5bDfsBbmR6vOTXdqIenCJFBaGTLeB5Id9ueFeR2Ntv-fPloVOi6a4Knb58nOsRB2g_Bo_2fADMgqufSBY1caVNSEClgmv2lq0ir4fmxL1-zvlM7thyLJn6hvzAdnUq6c_3xtYXNeISOjmNVmM01f6esqxw.Cz7E21zgWTuRsMSjOXTa6x3ZrMJ6PrZyG1CNUUof7Po&dib_tag=se&keywords=data%2Banalyst%2Btshirt&qid=1764148117&sprefix=data%2Banalyst%2Btshir%2Caps%2C310&sr=8-12&customId=B0752XJYNL&customizationToken=MC_Assembly_1%23B0752XJYNL&th=1&psc=1"
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'jayandrahamal203@gmail.com',
        msg
     
    )
